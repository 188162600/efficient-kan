# %%
from kan import KAN as BaseKAN
from kan import  create_dataset

from better_kan import KAN as BetterKAN

import torch
import time
device='cuda' if torch.cuda.is_available() else 'cpu'
n=10
steps=10

depths=[2,3,4]
features_list=[32,64,128]
for grid in [10,20,50]:
    
   
    base_kan_time={}
    better_kan_time={}
    times_scales={}
    for depth in depths:
        
        base_kan_t=[]
        base_kan_time[f"depth={depth}"]=base_kan_t
        better_kan_t=[]
        better_kan_time[f"depth={depth} "]=better_kan_t
        time_scale=[]
        times_scales[f"depth={depth} grids={grid}"]=time_scale
        for features in features_list:
            
            dataset=create_dataset(f=lambda x:x,n_var=features,train_num=n,test_num=n,device=device)
        # for kan in [BaseKAN, BetterKAN]:
           
            try :
                t=time.time()
                base_kan=BaseKAN(width=[features]*depth,grid=grid,device=device,symbolic_enabled=False)
                base_kan.train(dataset,opt="Adam",steps=steps,device=device,update_grid=False)
                base_time=time.time()-t
                base_kan_t.append(time.time()-t)
                print(f"features={features},grid={grid},depth={depth} class={BaseKAN},time={time.time()-t},time_per_step={(time.time()-t)/steps}")
                
            except Exception as e:
                print(f"features={features},grid={grid},depth={depth} class={BaseKAN},error={e}")
                base_kan_t.append(float('nan'))
                base_time=float('nan')
                
            try:
                    
                t=time.time()
                better_kan=BetterKAN(width=[features]*depth,num_basis=grid,device=device,symbolic_enabled=False).to(device)
                better_kan.train(dataset,opt="Adam",steps=steps,update_grid=False)
                better_kan_t.append(time.time()-t)
                print(f"features={features},grid={grid},depth={depth} class={BetterKAN},time={time.time()-t},time_per_step={(time.time()-t)/steps}")
                better_time=time.time()-t
            except Exception as e:
               
                better_kan_t.append(float('nan'))
                better_time=float('nan')
            print(f"features={features},grid={grid},depth={depth} time scale={base_time/better_time}")
            time_scale.append(base_time/better_time)
    import matplotlib.pyplot as plt 
    # plt.figure()
    plt.figure()
    for k,v in base_kan_time.items():
        plt.plot(v,label=k)
        plt.legend()
    plt.legend()
    plt.figure()
    for k,v in better_kan_time.items():
        plt.plot(v,label=k)
        plt.legend()
    ax,plot=plt.subplots()
    ax.set_size_inches(12,8)
    plot.set_prop_cycle(color=['black', 'red', 'blue'])

    for k,v in times_scales.items():
        plt.plot(features_list,v,label=k)
        plt.legend()
    plot.set_title(f"Relative Training Speed Improvement of New KAN Over Base KAN at Grid Size={grid}")
    plot.set_xlabel("input and output features")
    plot.set_ylabel("base kan trian time/new train kan time")
    # plt.set_xlabel("depth")
    # plt.set_ylabel("time")
    plt.show()
# Out:
# train loss: 6.10e+00 | test loss: 6.16e+00 | reg: 3.73e+02 : 100%|██| 10/10 [00:00<00:00, 12.62it/s]
# features=32,grid=10,depth=2 class=<class 'kan.KAN.KAN'>,time=0.9578723907470703,time_per_step=0.09578723907470703
# train loss: 3.31e+00 | test loss: 7.95e+00 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 137.98it/s]
# features=32,grid=10,depth=2 class=<class 'better_kan.KAN.KAN'>,time=0.08320856094360352,time_per_step=0.008320856094360351
# features=32,grid=10,depth=2 time scale=11.511704803983932
# train loss: 9.92e+00 | test loss: 1.01e+01 | reg: 1.38e+03 : 100%|█| 10/10 [00:00<00:00, 111.32it/s]
# features=64,grid=10,depth=2 class=<class 'kan.KAN.KAN'>,time=0.1607065200805664,time_per_step=0.01607065200805664
# train loss: 7.55e+00 | test loss: 1.05e+01 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 202.09it/s]
# features=64,grid=10,depth=2 class=<class 'better_kan.KAN.KAN'>,time=0.05659651756286621,time_per_step=0.005659651756286621
# features=64,grid=10,depth=2 time scale=2.839512517745584
# train loss: 1.77e+01 | test loss: 2.00e+01 | reg: 5.31e+03 : 100%|██| 10/10 [00:00<00:00, 79.09it/s]
# features=128,grid=10,depth=2 class=<class 'kan.KAN.KAN'>,time=0.3994414806365967,time_per_step=0.03994414806365967
# train loss: 1.51e+01 | test loss: 2.49e+01 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 105.55it/s]
# features=128,grid=10,depth=2 class=<class 'better_kan.KAN.KAN'>,time=0.10328793525695801,time_per_step=0.0103287935256958
# features=128,grid=10,depth=2 time scale=3.8672617440059462
# train loss: 7.77e+00 | test loss: 1.83e+00 | reg: 5.82e+03 : 100%|██| 10/10 [00:00<00:00, 51.19it/s]
# features=32,grid=10,depth=3 class=<class 'kan.KAN.KAN'>,time=0.24993109703063965,time_per_step=0.024993109703063964
# train loss: 7.28e+00 | test loss: 1.25e+01 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 133.10it/s]
# features=32,grid=10,depth=3 class=<class 'better_kan.KAN.KAN'>,time=0.0864105224609375,time_per_step=0.00864105224609375
# features=32,grid=10,depth=3 time scale=2.892368775384072
# train loss: 7.99e+01 | test loss: 1.91e+02 | reg: 2.07e+04 : 100%|██| 10/10 [00:00<00:00, 58.60it/s]
# features=64,grid=10,depth=3 class=<class 'kan.KAN.KAN'>,time=0.3787665367126465,time_per_step=0.03787665367126465
# train loss: 1.53e+01 | test loss: 1.03e+01 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 172.47it/s]
# features=64,grid=10,depth=3 class=<class 'better_kan.KAN.KAN'>,time=0.06373214721679688,time_per_step=0.006373214721679688
# features=64,grid=10,depth=3 time scale=5.943100197521996
# train loss: 1.65e+03 | test loss: 3.64e+02 | reg: 1.76e+05 : 100%|██| 10/10 [00:00<00:00, 45.08it/s]
# features=128,grid=10,depth=3 class=<class 'kan.KAN.KAN'>,time=1.1280896663665771,time_per_step=0.11280896663665771
# train loss: 1.82e+01 | test loss: 1.67e+01 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 127.22it/s]
# features=128,grid=10,depth=3 class=<class 'better_kan.KAN.KAN'>,time=0.09096026420593262,time_per_step=0.009096026420593262
# features=128,grid=10,depth=3 time scale=12.30671653631372
# train loss: 4.54e+00 | test loss: 4.58e+00 | reg: 8.01e+03 : 100%|██| 10/10 [00:00<00:00, 43.33it/s]
# features=32,grid=10,depth=4 class=<class 'kan.KAN.KAN'>,time=0.298720121383667,time_per_step=0.0298720121383667
# train loss: 1.16e+01 | test loss: 1.07e+01 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 133.29it/s]
# features=32,grid=10,depth=4 class=<class 'better_kan.KAN.KAN'>,time=0.08226418495178223,time_per_step=0.008226418495178222
# features=32,grid=10,depth=4 time scale=3.6312293321663223
# train loss: 5.57e+01 | test loss: 2.36e+00 | reg: 1.35e+05 : 100%|██| 10/10 [00:00<00:00, 44.47it/s]
# features=64,grid=10,depth=4 class=<class 'kan.KAN.KAN'>,time=0.45955848693847656,time_per_step=0.045955848693847653
# train loss: 1.64e+01 | test loss: 1.47e+01 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 118.49it/s]
# features=64,grid=10,depth=4 class=<class 'better_kan.KAN.KAN'>,time=0.09064149856567383,time_per_step=0.009064149856567384
# features=64,grid=10,depth=4 time scale=5.07006717905823
# train loss: 6.82e+04 | test loss: 5.20e+04 | reg: 6.47e+06 : 100%|██| 10/10 [00:00<00:00, 30.17it/s]
# features=128,grid=10,depth=4 class=<class 'kan.KAN.KAN'>,time=1.5123887062072754,time_per_step=0.15123887062072755
# train loss: 1.05e+01 | test loss: 3.11e+01 | reg: 0.00e+00 : 100%|██| 10/10 [00:00<00:00, 74.00it/s]
# features=128,grid=10,depth=4 class=<class 'better_kan.KAN.KAN'>,time=0.14980602264404297,time_per_step=0.014980602264404296
# features=128,grid=10,depth=4 time scale=10.09564688731435
# train loss: 6.42e+00 | test loss: 5.00e+00 | reg: 3.38e+02 : 100%|██| 10/10 [00:00<00:00, 73.51it/s]
# features=32,grid=20,depth=2 class=<class 'kan.KAN.KAN'>,time=0.17347192764282227,time_per_step=0.017347192764282225
# train loss: 3.86e+00 | test loss: 3.60e+00 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 148.90it/s]
# features=32,grid=20,depth=2 class=<class 'better_kan.KAN.KAN'>,time=0.07372736930847168,time_per_step=0.007372736930847168
# features=32,grid=20,depth=2 time scale=2.35288372920271
# train loss: 1.07e+01 | test loss: 7.74e+00 | reg: 1.20e+03 : 100%|██| 10/10 [00:00<00:00, 77.42it/s]
# features=64,grid=20,depth=2 class=<class 'kan.KAN.KAN'>,time=0.23303437232971191,time_per_step=0.02330343723297119
# train loss: 1.43e+01 | test loss: 3.25e+00 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 137.31it/s]
# features=64,grid=20,depth=2 class=<class 'better_kan.KAN.KAN'>,time=0.19884777069091797,time_per_step=0.019884777069091798
# features=64,grid=20,depth=2 time scale=1.1719234845832514
# train loss: 1.87e+01 | test loss: 1.63e+01 | reg: 5.33e+03 : 100%|██| 10/10 [00:00<00:00, 61.19it/s]
# features=128,grid=20,depth=2 class=<class 'kan.KAN.KAN'>,time=0.6068620681762695,time_per_step=0.06068620681762695
# train loss: 2.90e+01 | test loss: 1.15e+01 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 140.37it/s]
# features=128,grid=20,depth=2 class=<class 'better_kan.KAN.KAN'>,time=0.0802924633026123,time_per_step=0.00802924633026123
# features=128,grid=20,depth=2 time scale=7.558144852139882
# train loss: 4.43e+00 | test loss: 1.02e+02 | reg: 6.28e+03 : 100%|██| 10/10 [00:00<00:00, 45.95it/s]
# features=32,grid=20,depth=3 class=<class 'kan.KAN.KAN'>,time=0.2787489891052246,time_per_step=0.02787489891052246
# train loss: 7.74e+00 | test loss: 1.57e+01 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 116.02it/s]
# features=32,grid=20,depth=3 class=<class 'better_kan.KAN.KAN'>,time=0.09219193458557129,time_per_step=0.009219193458557129
# features=32,grid=20,depth=3 time scale=3.02357240205751
# train loss: 2.77e+02 | test loss: 1.12e+02 | reg: 2.80e+04 : 100%|██| 10/10 [00:00<00:00, 66.80it/s]
# features=64,grid=20,depth=3 class=<class 'kan.KAN.KAN'>,time=0.3639853000640869,time_per_step=0.03639853000640869
# train loss: 1.39e+01 | test loss: 1.60e+01 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 164.24it/s]
# features=64,grid=20,depth=3 class=<class 'better_kan.KAN.KAN'>,time=0.07571268081665039,time_per_step=0.007571268081665039
# features=64,grid=20,depth=3 time scale=4.807454922188423
# train loss: 7.88e+02 | test loss: 4.82e+02 | reg: 1.69e+05 : 100%|██| 10/10 [00:00<00:00, 29.31it/s]
# features=128,grid=20,depth=3 class=<class 'kan.KAN.KAN'>,time=1.2555081844329834,time_per_step=0.12555081844329835
# train loss: 1.04e+01 | test loss: 2.94e+01 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 147.57it/s]
# features=128,grid=20,depth=3 class=<class 'better_kan.KAN.KAN'>,time=0.19553875923156738,time_per_step=0.019553875923156737
# features=128,grid=20,depth=3 time scale=6.388081446481753
# train loss: 4.26e+00 | test loss: 1.18e+00 | reg: 1.29e+04 : 100%|██| 10/10 [00:00<00:00, 36.14it/s]
# features=32,grid=20,depth=4 class=<class 'kan.KAN.KAN'>,time=0.34519410133361816,time_per_step=0.034519410133361815
# train loss: 1.32e+01 | test loss: 1.68e+01 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 126.58it/s]
# features=32,grid=20,depth=4 class=<class 'better_kan.KAN.KAN'>,time=0.08454608917236328,time_per_step=0.008454608917236327
# features=32,grid=20,depth=4 time scale=4.082910335803639
# train loss: 5.80e+02 | test loss: 4.16e+02 | reg: 2.12e+05 : 100%|██| 10/10 [00:00<00:00, 35.08it/s]
# features=64,grid=20,depth=4 class=<class 'kan.KAN.KAN'>,time=0.5985414981842041,time_per_step=0.05985414981842041
# train loss: 2.33e+01 | test loss: 1.04e+01 | reg: 0.00e+00 : 100%|██| 10/10 [00:00<00:00, 75.50it/s]
# features=64,grid=20,depth=4 class=<class 'better_kan.KAN.KAN'>,time=0.14007902145385742,time_per_step=0.014007902145385743
# features=64,grid=20,depth=4 time scale=4.272884633059533
# train loss: nan | test loss: nan | reg: nan : 100%|█████████████████| 10/10 [00:00<00:00, 19.97it/s]
# features=128,grid=20,depth=4 class=<class 'kan.KAN.KAN'>,time=2.0385632514953613,time_per_step=0.20385632514953614
# train loss: 3.90e+01 | test loss: 2.29e+01 | reg: 0.00e+00 : 100%|██| 10/10 [00:00<00:00, 92.32it/s]
# features=128,grid=20,depth=4 class=<class 'better_kan.KAN.KAN'>,time=0.1261765956878662,time_per_step=0.012617659568786622
# features=128,grid=20,depth=4 time scale=16.156429331302682
# train loss: 7.13e+00 | test loss: 4.46e+00 | reg: 2.90e+02 : 100%|██| 10/10 [00:00<00:00, 79.56it/s]
# features=32,grid=50,depth=2 class=<class 'kan.KAN.KAN'>,time=1.4183456897735596,time_per_step=0.14183456897735597
# train loss: 7.19e+00 | test loss: 9.97e+00 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 128.65it/s]
# features=32,grid=50,depth=2 class=<class 'better_kan.KAN.KAN'>,time=0.14458823204040527,time_per_step=0.014458823204040527
# features=32,grid=50,depth=2 time scale=9.742081759183293
# train loss: 1.36e+01 | test loss: 7.21e+00 | reg: 1.31e+03 : 100%|██| 10/10 [00:00<00:00, 81.08it/s]
# features=64,grid=50,depth=2 class=<class 'kan.KAN.KAN'>,time=3.474682569503784,time_per_step=0.3474682569503784
# train loss: 2.05e+01 | test loss: 2.50e+01 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 142.28it/s]
# features=64,grid=50,depth=2 class=<class 'better_kan.KAN.KAN'>,time=0.07935166358947754,time_per_step=0.007935166358947754
# features=64,grid=50,depth=2 time scale=43.680390711168656
# train loss: 3.08e+01 | test loss: 1.50e+01 | reg: 8.85e+03 : 100%|██| 10/10 [00:00<00:00, 45.93it/s]
# features=128,grid=50,depth=2 class=<class 'kan.KAN.KAN'>,time=16.224995374679565,time_per_step=1.6224995374679565
# train loss: 4.23e+01 | test loss: 2.82e+01 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 158.54it/s]
# features=128,grid=50,depth=2 class=<class 'better_kan.KAN.KAN'>,time=0.17110753059387207,time_per_step=0.017110753059387206
# features=128,grid=50,depth=2 time scale=94.82338572923474
# train loss: 1.74e+02 | test loss: 1.73e+02 | reg: 1.44e+04 : 100%|██| 10/10 [00:00<00:00, 50.53it/s]
# features=32,grid=50,depth=3 class=<class 'kan.KAN.KAN'>,time=2.0678253173828125,time_per_step=0.20678253173828126
# train loss: 6.23e+00 | test loss: 7.52e+00 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 140.08it/s]
# features=32,grid=50,depth=3 class=<class 'better_kan.KAN.KAN'>,time=0.07473564147949219,time_per_step=0.007473564147949219
# features=32,grid=50,depth=3 time scale=27.66852971952122
# train loss: 2.05e+02 | test loss: 1.85e+02 | reg: 3.25e+04 : 100%|██| 10/10 [00:00<00:00, 27.92it/s]
# features=64,grid=50,depth=3 class=<class 'kan.KAN.KAN'>,time=7.394181251525879,time_per_step=0.7394181251525879
# train loss: 1.11e+01 | test loss: 1.37e+01 | reg: 0.00e+00 : 100%|██| 10/10 [00:00<00:00, 75.81it/s]
# features=64,grid=50,depth=3 class=<class 'better_kan.KAN.KAN'>,time=0.14003324508666992,time_per_step=0.014003324508666991
# features=64,grid=50,depth=3 time scale=52.80304149882011
# train loss: 6.42e+02 | test loss: 3.73e+02 | reg: 1.14e+05 : 100%|██| 10/10 [00:00<00:00, 20.44it/s]
# features=128,grid=50,depth=3 class=<class 'kan.KAN.KAN'>,time=36.68328905105591,time_per_step=3.6683289051055907
# train loss: 1.74e+01 | test loss: 2.82e+01 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 107.75it/s]
# features=128,grid=50,depth=3 class=<class 'better_kan.KAN.KAN'>,time=0.21274137496948242,time_per_step=0.02127413749694824
# features=128,grid=50,depth=3 time scale=172.43138085536063
# train loss: nan | test loss: nan | reg: nan : 100%|█████████████████| 10/10 [00:00<00:00, 38.42it/s]
# features=32,grid=50,depth=4 class=<class 'kan.KAN.KAN'>,time=3.764450788497925,time_per_step=0.3764450788497925
# train loss: 2.59e+01 | test loss: 1.42e+01 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 118.29it/s]
# features=32,grid=50,depth=4 class=<class 'better_kan.KAN.KAN'>,time=0.09047532081604004,time_per_step=0.009047532081604004
# features=32,grid=50,depth=4 time scale=41.60748759489935
# train loss: 4.39e+01 | test loss: 1.32e+00 | reg: 2.96e+05 : 100%|██| 10/10 [00:00<00:00, 31.01it/s]
# features=64,grid=50,depth=4 class=<class 'kan.KAN.KAN'>,time=13.909013032913208,time_per_step=1.390901303291321
# train loss: 3.01e+01 | test loss: 1.51e+01 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 106.30it/s]
# features=64,grid=50,depth=4 class=<class 'better_kan.KAN.KAN'>,time=0.09894919395446777,time_per_step=0.009894919395446778
# features=64,grid=50,depth=4 time scale=140.5672191661667
# train loss: 2.71e+00 | test loss: nan | reg: nan : 100%|████████████| 10/10 [00:00<00:00, 12.16it/s]
# features=128,grid=50,depth=4 class=<class 'kan.KAN.KAN'>,time=55.218032360076904,time_per_step=5.52180323600769
# train loss: 3.18e+01 | test loss: 8.28e+01 | reg: 0.00e+00 : 100%|██| 10/10 [00:00<00:00, 72.49it/s]
# features=128,grid=50,depth=4 class=<class 'better_kan.KAN.KAN'>,time=0.24221014976501465,time_per_step=0.024221014976501466
# features=128,grid=50,depth=4 time scale=227.97571618550197
