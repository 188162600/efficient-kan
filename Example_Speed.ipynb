# %%
from kan import KAN as BaseKAN
from kan import  create_dataset

from better_kan import KAN as BetterKAN

import torch
import time
device='cuda' if torch.cuda.is_available() else 'cpu'
n=10
steps=10

depths=[2,3,4]
features_list=[32,64,128]
for grid in [10,20,50]:
    
   
    base_kan_time={}
    better_kan_time={}
    times_scales={}
    for depth in depths:
        
        base_kan_t=[]
        base_kan_time[f"depth={depth}"]=base_kan_t
        better_kan_t=[]
        better_kan_time[f"depth={depth} "]=better_kan_t
        time_scale=[]
        times_scales[f"depth={depth} grids={grid}"]=time_scale
        for features in features_list:
            
            dataset=create_dataset(f=lambda x:x,n_var=features,train_num=n,test_num=n,device=device)
        # for kan in [BaseKAN, BetterKAN]:
           
            try :
                t=time.time()
                base_kan=BaseKAN(width=[features]*depth,grid=grid,device=device,symbolic_enabled=False)
                base_kan.train(dataset,opt="Adam",steps=steps,device=device,update_grid=False)
                base_time=time.time()-t
                base_kan_t.append(time.time()-t)
                print(f"features={features},grid={grid},depth={depth} class={BaseKAN},time={time.time()-t},time_per_step={(time.time()-t)/steps}")
                
            except Exception as e:
                print(f"features={features},grid={grid},depth={depth} class={BaseKAN},error={e}")
                base_kan_t.append(float('nan'))
                base_time=float('nan')
                
            try:
                    
                t=time.time()
                better_kan=BetterKAN(width=[features]*depth,num_basis=grid,device=device,symbolic_enabled=False).to(device)
                better_kan.train(dataset,opt="Adam",steps=steps,update_grid=False)
                better_kan_t.append(time.time()-t)
                print(f"features={features},grid={grid},depth={depth} class={BetterKAN},time={time.time()-t},time_per_step={(time.time()-t)/steps}")
                better_time=time.time()-t
            except Exception as e:
               
                better_kan_t.append(float('nan'))
                better_time=float('nan')
            print(f"features={features},grid={grid},depth={depth} time scale={base_time/better_time}")
            time_scale.append(base_time/better_time)
    import matplotlib.pyplot as plt 
    # plt.figure()
    plt.figure()
    for k,v in base_kan_time.items():
        plt.plot(v,label=k)
        plt.legend()
    plt.legend()
    plt.figure()
    for k,v in better_kan_time.items():
        plt.plot(v,label=k)
        plt.legend()
    ax,plot=plt.subplots()
    ax.set_size_inches(12,8)
    plot.set_prop_cycle(color=['black', 'red', 'blue'])

    for k,v in times_scales.items():
        plt.plot(features_list,v,label=k)
        plt.legend()
    plot.set_title(f"Relative Training Speed Improvement of New KAN Over Base KAN at Grid Size={grid}")
    plot.set_xlabel("input and output features")
    plot.set_ylabel("base kan trian time/new train kan time")
    # plt.set_xlabel("depth")
    # plt.set_ylabel("time")
    plt.show()
# Out:
# train loss: 6.10e+00 | test loss: 6.16e+00 | reg: 3.73e+02 : 100%|██| 10/10 [00:00<00:00, 45.51it/s]
# features=32,grid=10,depth=2 class=<class 'kan.KAN.KAN'>,time=0.3325634002685547,time_per_step=0.03325634002685547
# train loss: 3.31e+00 | test loss: 7.95e+00 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 154.87it/s]
# features=32,grid=10,depth=2 class=<class 'better_kan.KAN.KAN'>,time=0.06871366500854492,time_per_step=0.006871366500854492
# features=32,grid=10,depth=2 time scale=4.839843722892653
# train loss: 9.92e+00 | test loss: 1.01e+01 | reg: 1.38e+03 : 100%|██| 10/10 [00:00<00:00, 85.21it/s]
# features=64,grid=10,depth=2 class=<class 'kan.KAN.KAN'>,time=0.19709539413452148,time_per_step=0.01970953941345215
# train loss: 7.55e+00 | test loss: 1.05e+01 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 180.50it/s]
# features=64,grid=10,depth=2 class=<class 'better_kan.KAN.KAN'>,time=0.05946707725524902,time_per_step=0.005946707725524902
# features=64,grid=10,depth=2 time scale=3.314361546449205
# train loss: 1.77e+01 | test loss: 2.00e+01 | reg: 5.31e+03 : 100%|██| 10/10 [00:00<00:00, 82.33it/s]
# features=128,grid=10,depth=2 class=<class 'kan.KAN.KAN'>,time=0.39086461067199707,time_per_step=0.03908646106719971
# train loss: 1.51e+01 | test loss: 2.49e+01 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 155.40it/s]
# features=128,grid=10,depth=2 class=<class 'better_kan.KAN.KAN'>,time=0.07254266738891602,time_per_step=0.007254266738891601
# features=128,grid=10,depth=2 time scale=5.388065048345855
# train loss: 7.77e+00 | test loss: 1.83e+00 | reg: 5.82e+03 : 100%|██| 10/10 [00:00<00:00, 46.34it/s]
# features=32,grid=10,depth=3 class=<class 'kan.KAN.KAN'>,time=0.2543060779571533,time_per_step=0.02543060779571533
# train loss: 4.88e+00 | test loss: 5.25e+00 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 117.82it/s]
# features=32,grid=10,depth=3 class=<class 'better_kan.KAN.KAN'>,time=0.1578207015991211,time_per_step=0.01578207015991211
# features=32,grid=10,depth=3 time scale=1.6113607111132597
# train loss: 8.00e+01 | test loss: 1.90e+02 | reg: 2.07e+04 : 100%|██| 10/10 [00:00<00:00, 47.09it/s]
# features=64,grid=10,depth=3 class=<class 'kan.KAN.KAN'>,time=0.34019947052001953,time_per_step=0.03401994705200195
# train loss: 1.06e+01 | test loss: 1.37e+01 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 149.94it/s]
# features=64,grid=10,depth=3 class=<class 'better_kan.KAN.KAN'>,time=0.07285189628601074,time_per_step=0.007285189628601074
# features=64,grid=10,depth=3 time scale=4.669740773588425
# train loss: 1.61e+03 | test loss: 2.68e+02 | reg: 1.73e+05 : 100%|██| 10/10 [00:00<00:00, 44.73it/s]
# features=128,grid=10,depth=3 class=<class 'kan.KAN.KAN'>,time=0.6940906047821045,time_per_step=0.06940906047821045
# train loss: 1.70e+01 | test loss: 1.98e+01 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 149.66it/s]
# features=128,grid=10,depth=3 class=<class 'better_kan.KAN.KAN'>,time=0.07639718055725098,time_per_step=0.0076397180557250975
# features=128,grid=10,depth=3 time scale=9.085290840831
# train loss: 4.54e+00 | test loss: 4.58e+00 | reg: 8.01e+03 : 100%|██| 10/10 [00:00<00:00, 44.62it/s]
# features=32,grid=10,depth=4 class=<class 'kan.KAN.KAN'>,time=0.27887558937072754,time_per_step=0.027887558937072753
# train loss: 1.30e+01 | test loss: 8.29e+00 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 120.71it/s]
# features=32,grid=10,depth=4 class=<class 'better_kan.KAN.KAN'>,time=0.08885955810546875,time_per_step=0.008885955810546875
# features=32,grid=10,depth=4 time scale=3.1383859577573623
# train loss: nan | test loss: nan | reg: nan : 100%|█████████████████| 10/10 [00:00<00:00, 42.52it/s]
# features=64,grid=10,depth=4 class=<class 'kan.KAN.KAN'>,time=0.48375725746154785,time_per_step=0.048375725746154785
# train loss: 1.50e+01 | test loss: 1.12e+01 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 112.31it/s]
# features=64,grid=10,depth=4 class=<class 'better_kan.KAN.KAN'>,time=0.09721851348876953,time_per_step=0.009721851348876953
# features=64,grid=10,depth=4 time scale=4.975978752415613
# train loss: 9.51e+04 | test loss: 2.72e+04 | reg: 7.37e+06 : 100%|██| 10/10 [00:00<00:00, 25.78it/s]
# features=128,grid=10,depth=4 class=<class 'kan.KAN.KAN'>,time=1.096156358718872,time_per_step=0.1096156358718872
# train loss: 8.99e+00 | test loss: 3.16e+01 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 103.59it/s]
# features=128,grid=10,depth=4 class=<class 'better_kan.KAN.KAN'>,time=0.20631670951843262,time_per_step=0.02063167095184326
# features=128,grid=10,depth=4 time scale=5.312979066394717
# train loss: 6.42e+00 | test loss: 5.00e+00 | reg: 3.38e+02 : 100%|██| 10/10 [00:00<00:00, 84.21it/s]
# features=32,grid=20,depth=2 class=<class 'kan.KAN.KAN'>,time=0.17005491256713867,time_per_step=0.017005491256713866
# train loss: 3.86e+00 | test loss: 3.60e+00 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 212.72it/s]
# features=32,grid=20,depth=2 class=<class 'better_kan.KAN.KAN'>,time=0.054589271545410156,time_per_step=0.005458927154541016
# features=32,grid=20,depth=2 time scale=3.1151709439038453
# train loss: 1.07e+01 | test loss: 7.74e+00 | reg: 1.20e+03 : 100%|█| 10/10 [00:00<00:00, 113.39it/s]
# features=64,grid=20,depth=2 class=<class 'kan.KAN.KAN'>,time=0.17238450050354004,time_per_step=0.017238450050354005
# train loss: 1.43e+01 | test loss: 3.25e+00 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 195.53it/s]
# features=64,grid=20,depth=2 class=<class 'better_kan.KAN.KAN'>,time=0.057160139083862305,time_per_step=0.005716013908386231
# features=64,grid=20,depth=2 time scale=3.015816673409886
# train loss: 1.87e+01 | test loss: 1.63e+01 | reg: 5.33e+03 : 100%|██| 10/10 [00:00<00:00, 68.18it/s]
# features=128,grid=20,depth=2 class=<class 'kan.KAN.KAN'>,time=0.47557616233825684,time_per_step=0.047557616233825685
# train loss: 2.90e+01 | test loss: 1.15e+01 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 187.29it/s]
# features=128,grid=20,depth=2 class=<class 'better_kan.KAN.KAN'>,time=0.05844616889953613,time_per_step=0.005844616889953613
# features=128,grid=20,depth=2 time scale=8.136994627581677
# train loss: 4.43e+00 | test loss: 1.02e+02 | reg: 6.28e+03 : 100%|██| 10/10 [00:00<00:00, 41.25it/s]
# features=32,grid=20,depth=3 class=<class 'kan.KAN.KAN'>,time=0.2919020652770996,time_per_step=0.029190206527709962
# train loss: 1.37e+01 | test loss: 8.63e+00 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 140.70it/s]
# features=32,grid=20,depth=3 class=<class 'better_kan.KAN.KAN'>,time=0.07678651809692383,time_per_step=0.0076786518096923825
# features=32,grid=20,depth=3 time scale=3.75189536715269
# train loss: 2.77e+02 | test loss: 1.12e+02 | reg: 2.80e+04 : 100%|██| 10/10 [00:00<00:00, 61.10it/s]
# features=64,grid=20,depth=3 class=<class 'kan.KAN.KAN'>,time=0.41088056564331055,time_per_step=0.04108805656433105
# train loss: 8.22e+00 | test loss: 2.09e+01 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 150.12it/s]
# features=64,grid=20,depth=3 class=<class 'better_kan.KAN.KAN'>,time=0.07257509231567383,time_per_step=0.007257509231567383
# features=64,grid=20,depth=3 time scale=5.647872737879096
# train loss: 7.94e+02 | test loss: 4.87e+02 | reg: 1.71e+05 : 100%|██| 10/10 [00:00<00:00, 35.85it/s]
# features=128,grid=20,depth=3 class=<class 'kan.KAN.KAN'>,time=0.922996997833252,time_per_step=0.0922996997833252
# train loss: 1.97e+01 | test loss: 2.39e+01 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 151.53it/s]
# features=128,grid=20,depth=3 class=<class 'better_kan.KAN.KAN'>,time=0.07697391510009766,time_per_step=0.007697391510009766
# features=128,grid=20,depth=3 time scale=11.991036140398696
# train loss: 4.28e+00 | test loss: 1.18e+00 | reg: 1.29e+04 : 100%|██| 10/10 [00:00<00:00, 40.42it/s]
# features=32,grid=20,depth=4 class=<class 'kan.KAN.KAN'>,time=0.3181953430175781,time_per_step=0.03181953430175781
# train loss: 1.44e+01 | test loss: 1.15e+01 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 114.34it/s]
# features=32,grid=20,depth=4 class=<class 'better_kan.KAN.KAN'>,time=0.09227728843688965,time_per_step=0.009227728843688965
# features=32,grid=20,depth=4 time scale=3.448251984942086
# train loss: 5.79e+02 | test loss: 4.16e+02 | reg: 2.12e+05 : 100%|██| 10/10 [00:00<00:00, 32.82it/s]
# features=64,grid=20,depth=4 class=<class 'kan.KAN.KAN'>,time=0.6265158653259277,time_per_step=0.06265158653259277
# train loss: 1.83e+01 | test loss: 1.51e+01 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 103.33it/s]
# features=64,grid=20,depth=4 class=<class 'better_kan.KAN.KAN'>,time=0.10324811935424805,time_per_step=0.010324811935424805
# features=64,grid=20,depth=4 time scale=6.068060796113187
# train loss: nan | test loss: nan | reg: nan : 100%|█████████████████| 10/10 [00:00<00:00, 24.26it/s]
# features=128,grid=20,depth=4 class=<class 'kan.KAN.KAN'>,time=1.3889954090118408,time_per_step=0.1388995409011841
# train loss: 2.14e+01 | test loss: 2.45e+01 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 121.58it/s]
# features=128,grid=20,depth=4 class=<class 'better_kan.KAN.KAN'>,time=0.17145776748657227,time_per_step=0.017145776748657228
# features=128,grid=20,depth=4 time scale=8.101093519257564
# train loss: 7.13e+00 | test loss: 4.46e+00 | reg: 2.90e+02 : 100%|██| 10/10 [00:00<00:00, 90.35it/s]
# features=32,grid=50,depth=2 class=<class 'kan.KAN.KAN'>,time=0.7608687877655029,time_per_step=0.07608687877655029
# train loss: 7.19e+00 | test loss: 9.97e+00 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 199.07it/s]
# features=32,grid=50,depth=2 class=<class 'better_kan.KAN.KAN'>,time=0.05290031433105469,time_per_step=0.005290031433105469
# features=32,grid=50,depth=2 time scale=14.383067423832703
# train loss: 1.36e+01 | test loss: 7.21e+00 | reg: 1.31e+03 : 100%|██| 10/10 [00:00<00:00, 92.92it/s]
# features=64,grid=50,depth=2 class=<class 'kan.KAN.KAN'>,time=2.7208285331726074,time_per_step=0.27208285331726073
# train loss: 2.05e+01 | test loss: 2.50e+01 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 178.21it/s]
# features=64,grid=50,depth=2 class=<class 'better_kan.KAN.KAN'>,time=0.05700802803039551,time_per_step=0.005700802803039551
# features=64,grid=50,depth=2 time scale=47.72711190293966
# train loss: 3.08e+01 | test loss: 1.50e+01 | reg: 8.85e+03 : 100%|██| 10/10 [00:00<00:00, 43.36it/s]
# features=128,grid=50,depth=2 class=<class 'kan.KAN.KAN'>,time=10.451524496078491,time_per_step=1.045152449607849
# train loss: 4.23e+01 | test loss: 2.82e+01 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 151.96it/s]
# features=128,grid=50,depth=2 class=<class 'better_kan.KAN.KAN'>,time=0.07380318641662598,time_per_step=0.0073803186416625975
# features=128,grid=50,depth=2 time scale=141.6134587615045
# train loss: 1.29e+02 | test loss: 1.90e+02 | reg: 1.32e+04 : 100%|██| 10/10 [00:00<00:00, 54.91it/s]
# features=32,grid=50,depth=3 class=<class 'kan.KAN.KAN'>,time=1.4839801788330078,time_per_step=0.1483980178833008
# train loss: 5.97e+00 | test loss: 6.76e+00 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 150.59it/s]
# features=32,grid=50,depth=3 class=<class 'better_kan.KAN.KAN'>,time=0.0714712142944336,time_per_step=0.0071471214294433595
# features=32,grid=50,depth=3 time scale=20.537719631102238
# train loss: 1.85e+02 | test loss: 1.51e+02 | reg: 2.97e+04 : 100%|██| 10/10 [00:00<00:00, 50.05it/s]
# features=64,grid=50,depth=3 class=<class 'kan.KAN.KAN'>,time=5.333395719528198,time_per_step=0.5333395719528198
# train loss: 1.30e+01 | test loss: 1.32e+01 | reg: 0.00e+00 : 100%|█| 10/10 [00:00<00:00, 139.30it/s]
# features=64,grid=50,depth=3 class=<class 'better_kan.KAN.KAN'>,time=0.14870572090148926,time_per_step=0.014870572090148925
# features=64,grid=50,depth=3 time scale=35.86543736983279
# train loss: 7.13e+02 | test loss: 4.00e+02 | reg: 1.17e+05 : 100%|██| 10/10 [00:00<00:00, 18.33it/s]
# features=128,grid=50,depth=3 class=<class 'kan.KAN.KAN'>,time=28.238147020339966,time_per_step=2.8238147020339968
# train loss: 2.42e+01 | test loss: 2.10e+01 | reg: 0.00e+00 : 100%|██| 10/10 [00:00<00:00, 91.76it/s]
# features=128,grid=50,depth=3 class=<class 'better_kan.KAN.KAN'>,time=0.1271040439605713,time_per_step=0.01271040439605713
# features=128,grid=50,depth=3 time scale=222.16560654120232
# train loss: nan | test loss: nan | reg: nan : 100%|█████████████████| 10/10 [00:00<00:00, 18.37it/s]
# features=32,grid=50,depth=4 class=<class 'kan.KAN.KAN'>,time=4.453784704208374,time_per_step=0.4453784704208374
# train loss: 1.53e+01 | test loss: 1.13e+01 | reg: 0.00e+00 : 100%|██| 10/10 [00:00<00:00, 68.69it/s]
# features=32,grid=50,depth=4 class=<class 'better_kan.KAN.KAN'>,time=0.15755271911621094,time_per_step=0.015755271911621092
# features=32,grid=50,depth=4 time scale=28.26853594905754
# train loss: 4.31e+01 | test loss: 1.32e+00 | reg: 2.96e+05 : 100%|██| 10/10 [00:00<00:00, 22.03it/s]
# features=64,grid=50,depth=4 class=<class 'kan.KAN.KAN'>,time=15.782468318939209,time_per_step=1.578246831893921
# train loss: 3.11e+01 | test loss: 2.71e+01 | reg: 0.00e+00 : 100%|██| 10/10 [00:00<00:00, 67.13it/s]
# features=64,grid=50,depth=4 class=<class 'better_kan.KAN.KAN'>,time=0.239393949508667,time_per_step=0.0239393949508667
# features=64,grid=50,depth=4 time scale=65.9267636100712
# train loss: 2.71e+00 | test loss: nan | reg: nan : 100%|████████████| 10/10 [00:00<00:00, 11.14it/s]
# features=128,grid=50,depth=4 class=<class 'kan.KAN.KAN'>,time=54.01553773880005,time_per_step=5.401553773880005
# train loss: 2.87e+01 | test loss: 1.46e+01 | reg: 0.00e+00 : 100%|██| 10/10 [00:00<00:00, 62.91it/s]
# features=128,grid=50,depth=4 class=<class 'better_kan.KAN.KAN'>,time=0.28154420852661133,time_per_step=0.028154420852661132
# features=128,grid=50,depth=4 time scale=191.85455108977865
